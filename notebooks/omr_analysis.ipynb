# %% [markdown]
# # Harmonia Occulta: OMR Analysis
#
# This notebook reproduces the Optical Music Recognition (OMR) analysis of Robert Fludd's Monochordum Mundi.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2
from pathlib import Path
import pandas as pd

# Set up paths
DATA_DIR = Path('../data')
IMAGES_DIR = DATA_DIR / 'images'
OUTPUTS_DIR = Path('../outputs')
OUTPUTS_DIR.mkdir(exist_ok=True, parents=True)
